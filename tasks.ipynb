# %% [markdown]
# # Tasks

# %% [markdown]
# ## Task 1: Source the Data Set

# %%
# Data frames

import pandas as pd

# Machine Learning Library that contains example datasets
import sklearn as sk1

# %%
# Load the iris dataset form csv file
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
# Show data
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# The load_iris() function returns the iris flower dateset. The dataset consits of three classes of flower types with 50 samples per class in a table format of 150 rows and 5 columns. The features of each flower are sepal length , sepal width, petal length and petal width all recoded in cm.

# %% [markdown]
# ## Task 2: Explore the Data Structure

# %%
# Load the dataset.
data = sk1.datasets.load_iris()

# %%
# show data 
# data

# %%
# The first and last 5 rows of the data
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html
sliced_data = pd.concat([df.iloc[:5], df.iloc[-5:]]) # This selects the first 5 and last 5 rows of the data; Concat adds these into a single data frame
print(sliced_data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Look at the data.
data.keys() # This show the keys of the data dictionary
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
# The feature names.
data['feature_names'] # This shows the feature names of the data
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
#The target.
data.target_names # This shows the target names of the data
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ## Task 3: Summarize the Data

# %%
# Describe the data set.
# https://pandas.pydata.org/docs/reference/frame.html
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html

numeric_df = df.select_dtypes(include=['float64', 'int64']) # Filters the DF to Exclude non-numeric columns

features = numeric_df.describe().T  # Describe computes the summary statistics for each column
features["median"] = numeric_df.median().values # Adds the median to the summary statistics
print(features[["mean", "min", "max", "std", "median"]]) # Prints the summary statistics
# Out:
#                   mean  min  max       std  median
# sepal_length  5.843333  4.3  7.9  0.828066    5.80
# sepal_width   3.054000  2.0  4.4  0.433594    3.00
# petal_length  3.758667  1.0  6.9  1.764420    4.35
# petal_width   1.198667  0.1  2.5  0.763161    1.30

# %% [markdown]
# ## Task 4: Visualize Features

# %%
# Plotting.
import matplotlib.pyplot as plt  # Matplotlib is a plotting library

# seaborn 
import seaborn as sns # Seaborn is a data visualization library based on Matplotlib

# Numerical arrays. 
import numpy as np # NumPy is a library for numerical computing in Python

# %%
# https://python-graph-gallery.com/528-customizing-histogram-with-pandas/#:~:text=Adding%20titles%20and%20names%20to,()%20)%20functions%20to%20add%20them.

# ax = plt.hist(df['sepal_length'], edgecolor='black', label='sepal_length', alpha=0.5)
# ax is the histogram object, creates a histogram for the specific feature column  "sepal_length"
ax = df["sepal_length"].hist(grid=False, # Remove grid
                        xlabelsize=10, # Change size of labels on the x-axis
                        ylabelsize=12, # Change size of labels on the y-axis
                        # bins=20, # Number of bins
                        # edgecolor='black', # Color of the border
                        # color='orange', # Color of the bins
                        rwidth=0.9 # Space between bins
                        # legend =('sepal_length')
                       )
ax.set_title('Iris Data Features', weight='bold') 

# Add label names
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Frequency')

# Show the plot
ax = plt.show()

# %%
# ax is the histogram object, creates a histogram for the specific feature column  "sepal_width"
ax = df["sepal_width"].hist(grid=False, # Remove grid
                        xlabelsize=10, # Change size of labels on the x-axis
                        ylabelsize=12, # Change size of labels on the y-axis
                        # bins=20, # Number of bins
                        # edgecolor='black', # Color of the border
                        # color='orange', # Color of the bins
                        rwidth=0.9, # Space between bins
                        # legend =('sepal_width')
                       )
ax.set_title('Iris Data Features', weight='bold') 

# Add label names
ax.set_xlabel('sepal_width')
ax.set_ylabel('Frequency')

# Show the plot
ax = plt.show()

# %%
# ax is the histogram object, creates a histogram for the specific feature column  "petal_length"
ax = df["petal_length"].hist(grid=False, # Remove grid
                        xlabelsize=10, # Change size of labels on the x-axis
                        ylabelsize=12, # Change size of labels on the y-axis
                        # bins=20, # Number of bins
                        # edgecolor='black', # Color of the border
                        # color='orange', # Color of the bins
                        rwidth=0.9, # Space between bins
                        # legend =('petal_length')
                       )
ax.set_title('Iris Data Features', weight='bold') 

# Add label names
ax.set_xlabel('petal_length')
ax.set_ylabel('Frequency')

# Show the plot
ax = plt.show()

# %%
# ax is the histogram object, creates a histogram for the specific feature column  "petal_width"
ax = df["petal_width"].hist(grid=False, # Remove grid
                        xlabelsize=10, # Change size of labels on the x-axis
                        ylabelsize=12, # Change size of labels on the y-axis
                        # bins=20, # Number of bins
                        # edgecolor='black', # Color of the border
                        # color='orange', # Color of the bins
                        rwidth=0.9, # Space between bins
                        # legend =('petal_width')
                       )
ax.set_title('Iris Data Features', weight='bold') 

# Add label names
ax.set_xlabel('petal_width')
ax.set_ylabel('Frequency')

# Show the plot
ax = plt.show()

# %%
plt.hist(df['sepal_length'], edgecolor='black', label='sepal_length', alpha=0.5) # plt.hist() is a function that creates a histogram alll the features are combined into a single histogram
plt.hist(df['sepal_width'], edgecolor='black', label='sepal_width', alpha=0.5)
plt.hist(df['petal_length'], edgecolor='black', label='petal_length', alpha=0.5)
plt.hist(df['petal_width'], edgecolor='black', label='petal_width', alpha=0.5)
plt.legend()

# %% [markdown]
# ## Task 5: Investigate Relationships

# %%
# The below is taken from this reference: https://chatgpt.com/share/6800af18-dda8-8006-8b67-cb49136ecbee
df = pd.DataFrame(data.data, columns=data.feature_names) # this converts the data into a pandas DataFrame
df['target'] = data.target # this adds the target column to the DataFrame

# Create a figure and an axis.
fig, ax = plt.subplots() 

# Scatter plot.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/legend.html
for target, color, label in zip([0, 1, 2], ['black', 'green', 'yellow'], data.target_names): # Iterate over three classes (0, 1, 2) (setosa, versicolor, virginica) in different colors.
    subset = df[df['target'] == target] # This creates a subset of the DataFrame for each target class.
    ax.scatter(subset['sepal length (cm)'], subset['sepal width (cm)'],  # This filters the DF for features called 'sepal length (cm)' and 'sepal width (cm)'
               c=color, label=label, marker='o')

# Labels.
ax.set_xlabel('Sepal_length')
ax.set_ylabel('Sepal_width')

# legend
ax.legend( title='classes')
plt.show()

# %% [markdown]
# ## Task 6: Analyze Relationship

# %%
# The below is taken from this reference: https://chatgpt.com/share/6800af18-dda8-8006-8b67-cb49136ecbee
df = pd.DataFrame(data.data, columns=data.feature_names) # this converts the data into a pandas DataFrame
df['target'] = data.target # this adds the target column to the DataFrame

# Create a figure and an axis.
fig, ax = plt.subplots()

# Scatter plot.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/legend.html

for target, color, label in zip([0, 1, 2], ['black', 'green', 'yellow'], data.target_names): # Iterate over three classes (0, 1, 2) (setosa, versicolor, virginica) in different colors.
    subset = df[df['target'] == target] # This creates a subset of the DataFrame for each target class.
    ax.scatter(subset['sepal length (cm)'], subset['sepal width (cm)'], # This filters the DF for features called 'sepal length (cm)' and 'sepal width (cm)'
               c=color, label=label, marker='o')


# Labels.
ax.set_xlabel('Sepal_length')
ax.set_ylabel('Sepal_width')

# legend
ax.legend( title='classes')

# Below uses numpy.polyfit to add a regression line to the scatter plot from Task 5 above.

x=subset['sepal length (cm)']
y=subset['sepal width (cm)']

# ax.scatter(x, y)
m, c = np.polyfit(x, y, 1) # This fits a regression line to the data using numpy.polyfit. m is the slope and c is the y-intercept of the line.

ax.plot(x, m * x + c, color='red'); # this plots the line

# %% [markdown]
# ## Task 7: Analyze Class Distributions

# %%
# Below creates Box-plots of the petal lengths for each of the three classes
# Add petal_length boxplots for each class
fig, ax = plt.subplots()

# Create boxplot data grouped by class
# https://chatgpt.com/share/680376d7-0e34-8006-88eb-1004c392dd33
box_data = [df[df['target'] == i]['petal length (cm)'] for i in range(3)]

# Create boxplot
ax.boxplot(box_data)

# Add class labels (0, 1, 2 typically correspond to setosa, versicolor, virginica)
ax.set_xticklabels(['Setosa', 'Versicolor', 'Virginica'])

ax.set_title('Petal Lengths by Class')
ax.set_ylabel('Petal Length (cm)')
# Out:
# Text(0, 0.5, 'Petal Length (cm)')

# %% [markdown]
# ## Task 8: Compute Correlations

# %%
# Calculate the correlation coefficients between the features.
# Display the results as a heatmap using matplotlib.
# https://zion-oladiran.medium.com/exploratory-data-analysis-iris-dataset-68897497b120

import seaborn as sns # Seaborn is a data visualisation library based on Matplotlib
import matplotlib.pyplot as plt # Matplotlib is a plotting library

df = pd.DataFrame(data.data, columns=data.feature_names) # this converts the data into a pandas DataFrame
df['target'] = data.target # this adds the target column to the DataFrame

correlation_coeff = df.corr() # This calculates the correlation coefficients between the features in the DataFrame. The result is a correlation matrix shown as heatmap below.
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_coeff, annot=True, cmap='coolwarm', fmt='.2f') # This creates a heatmap of the correlation coefficients using seaborn.
plt.title('Correlation Coefficients of Iris Dataset Features')
plt.show()

# %% [markdown]
# ## Task 9: Fit a Simple Linear Regression

# %% [markdown]
# For the two features in Task 5, calculate the coefficient of determination R2.

# %%
# The below is taken from this reference: https://chatgpt.com/share/6800af18-dda8-8006-8b67-cb49136ecbee
df = pd.DataFrame(data.data, columns=data.feature_names) # this converts the data into a pandas DataFrame
df['target'] = data.target # this adds the target column to the DataFrame

# Create a figure and an axis.
fig, ax = plt.subplots()

# Scatter plot.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/legend.html

for target, color, label in zip([0, 1, 2], ['black', 'green', 'yellow'], data.target_names): # Iterate over three classes (0, 1, 2) (setosa, versicolor, virginica) in different colors.
    subset = df[df['target'] == target] # This creates a subset of the DataFrame for each target class.
    ax.scatter(subset['sepal length (cm)'], subset['sepal width (cm)'], # This filters the DF for features called 'sepal length (cm)' and 'sepal width (cm)'
               c=color, label=label, marker='o')

# Labels.
ax.set_xlabel('Sepal_length')
ax.set_ylabel('Sepal_width')

# legend
ax.legend( title='classes')
plt.show()

# %%
# Use scipy to fit a line.
import scipy as sp

# %%
# Use scipy to fit a line.
fit = sp.stats.linregress(subset['sepal length (cm)'], subset['sepal width (cm)'])
# fit slope
fit.slope
# fit intercept
fit.intercept
# R value
fit.rvalue
# R^2 value
fit.rvalue**2
# Out:
# np.float64(0.20905727608452862)

# %% [markdown]
# Re-create the plot from Task 6 and annotate it with the R2 value.

# %%
# The below is taken from this reference: https://chatgpt.com/share/6800af18-dda8-8006-8b67-cb49136ecbee
df = pd.DataFrame(data.data, columns=data.feature_names) # this converts the data into a pandas DataFrame
df['target'] = data.target # this adds the target column to the DataFrame

# Create a figure and an axis.
fig, ax = plt.subplots()

# Scatter plot.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/legend.html

for target, color, label in zip([0, 1, 2], ['black', 'green', 'yellow'], data.target_names): # Iterate over three classes (0, 1, 2) (setosa, versicolor, virginica) in different colors.
    subset = df[df['target'] == target] # This creates a subset of the DataFrame for each target class.
    ax.scatter(subset['sepal length (cm)'], subset['sepal width (cm)'],  # This filters the DF for features called 'sepal length (cm)' and 'sepal width (cm)'
               c=color, label=label, marker='o')


# Labels.
ax.set_xlabel('Sepal_length')
ax.set_ylabel('Sepal_width')

ax.legend( title='classes')

# Below uses numpy.polyfit to add a regression line to the scatter plot from Task 5 above.

x=subset['sepal length (cm)']
y=subset['sepal width (cm)']

# ax.scatter(x, y)
m, c = np.polyfit(x, y, 1)  # This fits a regression line to the data using numpy.polyfit. m is the slope and c is the y-intercept of the line.

ax.plot(x, m * x + c, color='red'); # this plots the line
# Use scipy to fit a line.
fit = sp.stats.linregress(subset['sepal length (cm)'], subset['sepal width (cm)']) # This uses scipy to fit a line to the data
# fit slope
fit.slope
# fit intercept
fit.intercept
# R value
fit.rvalue
# R^2 value
r_squared=fit.rvalue**2

# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.text.html
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/legend.html#legend-with-bounding-box
ax.text(0.05, 0.95, f"$R^2 = {r_squared:.2f}$", transform=ax.transAxes, 
        fontsize=12, verticalalignment='top', bbox=dict(boxstyle="round", facecolor="white", alpha=0.5)) # This adds the R^2 value to the plot

plt.show()

# %% [markdown]
# ## Task 10: Too Many Features

# %%
# Using seaborn to create a pairplot of the data set.
# https://seaborn.pydata.org/generated/seaborn.pairplot.html
# https://www.tutorialspoint.com/plotting-graph-for-iris-dataset-using-seaborn-and-matplotlib#:~:text=The%20pairplot()%20function%20from,on%20the%20species%20of%20Iris.

import seaborn as sns # Seaborn is a data visualisation library based on Matplotlib
import matplotlib.pyplot as plt # Matplotlib is a plotting library

# Load the Iris dataset
iris = sns.load_dataset('iris') 

# Create the pairplot
sns.pairplot(iris, hue='species') # hue is used to color the points by species

# Display the plot
plt.show()

# %% [markdown]
# ### Pairplot

# %% [markdown]
# Pairplot depicts the relationship between each pair of features in the three species of the dataset.
# The scatter plots show the relationship between two features, while  the diagonal show the distribution of each feature. The plo show how well the features separate the species.

# %% [markdown]
# ## End
